# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nsteps = 10000
a = 1
b = 1 
c = 0.5
d = 1
dt = 0.005

x = np.zeros(nsteps)
y = np.zeros(nsteps)
x[0]= 1
y[0]= 1

for t in range(1,nsteps):
    x[t]= x[t-1] + dt*(a*x[t-1]- b*x[t-1]*y[t-1])
    y[t]= y[t-1] + dt*(c*x[t-1]*y[t-1]-d*y[t-1])
    
fig = plt.figure()
plt.plot(x, label='Bunnies');
plt.plot(y, label='foxes');
plt.legend(loc='upper right');



fig = plt.figure(figsize=(5,5));
plt.plot(x,y, label =d);
plt.xlabel('bunnies');
plt.ylabel('foxes');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-e7905bd237ea> in <module>
#      24 fig = plt.figure(figsize=(5,5));
#      25 plt.plot(x,y, label =d);
# ---> 26 plt.xlabel('bunnies');
#      27 plt.ylabel('foxes');
#
# TypeError: 'str' object is not callable

# %%
plt.plot(x,y);
plt.xlabel('bunnies');
plt.ylabel('foxes');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-e15a78cb91e3> in <module>
#       1 plt.plot(x,y);
# ----> 2 plt.xlabel('bunnies');
#       3 plt.ylabel('foxes');
#
# TypeError: 'str' object is not callable
