# %% [markdown]
# # Prediction Horizon with changes to R
# ### By next Monday, please explore how the prediction horizon for the logistic equation changes with changes in r. You can do it manually (not recommended), or you can try to write a program that would do it automatically (better!). But either way, try to figure it out. Make it a new notebook; describe your thinking and your conclusions as some markdown cells, interspersed with code, and post a link to this notebook as a follow-up to this post, below.
#
# ### There is no single correct answer to this question, so it is mostly the logic and consistency of your thinking that matters. Please try to describe your reasoning and your results as clearly as possible.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nsteps = 100              # Number of steps in our lil simulation
ntraces = 5              #Simplyified mumber of ntraces to see different trajectories 
x = np.zeros(shape=(nsteps,ntraces))    # A placeholder for the trajectories we'll generate. Each will be a column.
wiggle = 0.0001                         # The standard deviation of the original noise in x0
r_value = (1,5)          #I believe that by adding this step I have now 

for r in np.arange(1,5):  
    for itrace in range(ntraces):
        x[0,itrace] = 0.6+np.random.randn(1)*wiggle
        for istep in range(1,nsteps):
            x[istep,itrace] = r*x[istep-1,itrace]*(1-x[istep-1,itrace])

figb = plt.figure(figsize=(15,5))
plt.plot(x)
plt.xlabel('Time');
plt.ylabel('Variability of Trajectories');

# %% [markdown]
# ### I wanted to make a run that allowed me to plot the trajectories between 1 and 5, so I made the values of r vary between 1 and 5. Althought, when substituting different numbers in for "5" the graph becomes more aligned when plotting the trajectories.

# %%
nsteps = 100              # Number of steps in our lil simulation
ntraces = 5              #Simplyified mumber of ntraces to see different trajectories 
x = np.zeros(shape=(nsteps,ntraces))    # A placeholder for the trajectories we'll generate. Each will be a column.
wiggle = 0.0001                         # The standard deviation of the original noise in x0
r_value = (1,5)          #I believe that by adding this step I have now 

for r in np.arange(1,3):  #R value between 1 and 3
    for itrace in range(ntraces):
        x[0,itrace] = 0.6+np.random.randn(1)*wiggle
        for istep in range(1,nsteps):
            x[istep,itrace] = r*x[istep-1,itrace]*(1-x[istep-1,itrace])

figb = plt.figure(figsize=(15,5))
plt.plot(x)
plt.xlabel('Time');
plt.ylabel('Variability of Trajectories');

# %%
nsteps = 100              # Number of steps in our lil simulation
ntraces = 5              #Simplyified mumber of ntraces to see different trajectories 
x = np.zeros(shape=(nsteps,ntraces))    # A placeholder for the trajectories we'll generate. Each will be a column.
wiggle = 0.0001                         # The standard deviation of the original noise in x0
r_value = (1,5)          #I believe that by adding this step I have now 

for r in np.arange(1,4):  # R-value between 1 and 4
    for itrace in range(ntraces):
        x[0,itrace] = 0.6+np.random.randn(1)*wiggle
        for istep in range(1,nsteps):
            x[istep,itrace] = r*x[istep-1,itrace]*(1-x[istep-1,itrace])

figb = plt.figure(figsize=(15,5))
plt.plot(x)
plt.xlabel('Time');
plt.ylabel('Variability of Trajectories');

# %%
nsteps = 100              # Number of steps in our lil simulation
ntraces = 5              #Simplyified mumber of ntraces to see different trajectories 
x = np.zeros(shape=(nsteps,ntraces))    # A placeholder for the trajectories we'll generate. Each will be a column.
wiggle = 0.0001                         # The standard deviation of the original noise in x0
r_value = (1,5)          #I believe that by adding this step I have now 

for r in np.arange(1,6):  # R-value between 1 and 6 
    for itrace in range(ntraces):
        x[0,itrace] = 0.6+np.random.randn(1)*wiggle
        for istep in range(1,nsteps):
            x[istep,itrace] = r*x[istep-1,itrace]*(1-x[istep-1,itrace])

figb = plt.figure(figsize=(15,5))
plt.plot(x)
plt.xlabel('Time');
plt.ylabel('Variability of Trajectories');
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
