# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nsteps = 20000
a = 0.6
b = 1.2
c = 0.5
d = 1
e = 1.5 #I wanted an additional predator, that hunted foxes... ,maybe dragons 

dt = 0.001

possible_ds = [0.5, 1, 1.5, 2]


x = np.zeros(nsteps)
y = np.zeros(nsteps)

fig1 = plt.figure(figsize=(16,5));
fig2 = plt.figure(figsize=(5,5));
ax2 = plt.axes()

for itrial in range(len(possible_ds)):
    d = possible_ds[itrial]
    e = possible_ds[itrial]
    x[0] = 1
    y[0] = 1

    for t in range(1,nsteps):
        x[t] = x[t-1] + dt*(a*x[t-1] - b*x[t-1]*y[t-1])*e # I multiplied my equation for fox predation rate by dragons
        y[t] = y[t-1] + dt*(c*x[t-1]*y[t-1] - d*y[t-1]) 

    ax1 = fig1.add_subplot(1,len(possible_ds),itrial+1)
    ax1.plot(x, label='Bunnies');
    ax1.plot(y, label='Foxes');
    ax1.legend(loc='upper right');

    ax2.plot(x,y, label=d);
    plt.xlabel('Bunnies');
    plt.ylabel('Foxes');
    
 
ax2.legend(loc='upper right');

# %% [markdown]
# ##### So, I don't know if I got my graph to work the way that I wanted to. I wanted to see a graph that fluctuated when I added a predator to foxes in my scenario. I felt like I shouldv'e seen a population increase in bunnies every time the dragons came back to feast on the foxes, but instead it looks like the scenario I created basically kills off foxes until there's enough food to bring back foxes into the population. Even then the foxes can only reach a maxmimum population of "1.3" because any more foxes will probably get killed by dragons.  I multiplied the equation for the population of foxes by the predation rate of the foxes by dragons.
